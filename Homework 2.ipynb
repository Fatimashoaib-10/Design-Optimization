# %% [markdown]
# # code for Problem 2
# import numpy as np
# from numpy import linalg as LNG
#
# #obj = lambda x: (2 - 2 * x[0] - 3 * x[1]) ** 2 + x[0] ** 2 + (x[1] - 1) ** 2  # convex function
# def obj(x):
#     return (2 - 2 * x[0] - 3 * x[1]) ** 2 + x[0] ** 2 + (x[1] - 1) ** 2
#
# def grad(x):  # grad
#     gd = [10 * x[0] - 8 + 12 * x[1], 20 * x[1] - 14 + 12 * x[0]]
#     return gd
# H = [[10 , 12],[12 20]]
#
#
# eps = 1e-2
# x0 = [0, 0]
# k = 0
# soln = [x0]  # use an array to store the search steps
# x = soln[k]  # start with the initial guess
# error = LNG.norm(grad(x))  # compute the error.
# #a = 0.01  # set a fixed step size to start with
#
# # Armijo line search
# def line_search(x):
#     a = 1.  # initialize step size
#     d = np.negative(grad(x))  # for gradient descent
#     # d = np.matmul(LNG.inv(H),grad(x)) for newton's method
#     phi = lambda a, x: obj(x) - a * 0.8 * np.matmul(np.transpose(grad(x)),d)  # define phi as a search criterion
#     while phi(a, x) < obj(x - a * d):  # if f(x+a*d)>phi(a) then backtrack. d is the search direction
#         a = 0.5 * a
#     return a
# #np.dot(a, (grad(x)))
#
# while error >= eps:  # keep searching while gradient norm is larger than eps
#      a = line_search(x)
#      x = x - np.dot(a, (grad(x)))
#      soln = np.append(soln, [x], axis = 0)
#      print(soln)
#      error =  LNG.norm(grad(x))#np.linalg.norm(grad(x))
#
# soln  # print the search trajectory

# %% [markdown]
# Question 5
# [Q5_1.jpeg](attachment:Q5_1.jpeg)
# ![Q5.jpeg](attachment:Q5.jpeg)
# [Q5_2.jpeg](attachment:Q5_2.jpeg)

# %% [markdown]
# ![Q3_1.jpeg](attachment:Q3_1.jpeg)

# %% [markdown]
# Question 3
#
# ![Q3_2.jpeg](attachment:Q3_2.jpeg)

# %% [markdown]
# # Design Problems
#
# ### Problem 5 (20 points)
# Consider an illumination problem: There are $n$ lamps and $m$ mirrors fixed to the ground. The target reflection intensity level is $I_t$. The actual reflection intensity level on the $k$th mirror can be computed as $\textbf{a}_k^T \textbf{p}$, where $\textbf{a}_k$ is given by the distances between all lamps to the mirror, and $\textbf{p}:=[p_1,...,p_n]^T$ are the power output of the lamps. The objective is to keep the actual intensity levels as close to the target as possible by tuning the power output $\textbf{p}$.
#
# * (5 points) Formulate this problem as an optimization problem.
# * (5 points) Is your problem convex?
# * (5 points) If we require the overall power output of any of the $n$ lamps to be less than $p^*$, will the problem have a unique solution?
# * (5 points) If we require no more than half of the lamps to be switched on, will the problem have a unique solution?

# %% [markdown]
# Question 2
# ![Q2_1.jpeg](attachment:Q2_1.jpeg)

# %% [markdown]
# ![Q2_2.jpeg](attachment:Q2_2.jpeg)

# %% [markdown]
# Question 1
# ![Q1_1.jpeg](attachment:Q1_1.jpeg)
